# %%
import pandas as pd

# %% [markdown]
# source = https://www.kaggle.com/datasets/leonardopena/top-spotify-songs-from-20102019-by-year

# %% [markdown]
# ### Load and cleanup the Data

# %%
data = pd.read_csv('top10s.csv',encoding='latin-1')

# %%
data.head()
# Out:
#                   title      artist        top genre  year  bpm  energy  \
# 0      Hey, Soul Sister       Train       neo mellow  2010   97      89
# 1  Love The Way You Lie      Eminem  detroit hip hop  2010   87      93
# 2               TiK ToK       Kesha        dance pop  2010  120      84
# 3           Bad Romance   Lady Gaga        dance pop  2010  119      92
# 4  Just the Way You Are  Bruno Mars              pop  2010  109      84
#
#    danceability  loudness  liveliness  valence  duration_sec  acousticness  \
# 0            67        -4           8       80           217            19
# 1            75        -5          52       64           263            24
# 2            76        -3          29       71           200            10
# 3            70        -4           8       71           295             0
# 4            64        -5           9       43           221             2
#
#    speechniness  popularity
# 0             4          83
# 1            23          82
# 2            14          80
# 3             4          79
# 4             4          78

# %%
# find out the shape of the data
data.shape
# Out:
# (603, 15)

# %%
# After load, show datasets info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  603 non-null    int64
#  1   title       603 non-null    object
#  2   artist      603 non-null    object
#  3   top genre   603 non-null    object
#  4   year        603 non-null    int64
#  5   bpm         603 non-null    int64
#  6   nrgy        603 non-null    int64
#  7   dnce        603 non-null    int64
#  8   dB          603 non-null    int64
#  9   live        603 non-null    int64
#  10  val         603 non-null    int64
#  11  dur         603 non-null    int64
#  12  acous       603 non-null    int64
#  13  spch        603 non-null    int64
#  14  pop         603 non-null    int64
# dtypes: int64(12), object(3)
# memory usage: 70.8+ KB

# %%
# figure out the null values (if any)
data.isnull().sum()
# Out:
# Unnamed: 0    0
# title         0
# artist        0
# top genre     0
# year          0
# bpm           0
# nrgy          0
# dnce          0
# dB            0
# live          0
# val           0
# dur           0
# acous         0
# spch          0
# pop           0
# dtype: int64

# %%
# droup out the duplicates observation (if any)
data = data.drop_duplicates()

# %%
# check out the datasets' shape again. seems that there're no duplicated observations identified
data.shape
# Out:
# (603, 15)

# %%
# statistically describe the data
data.describe()
# Out:
#        Unnamed: 0         year         bpm        nrgy        dnce  \
# count  603.000000   603.000000  603.000000  603.000000  603.000000
# mean   302.000000  2014.592040  118.545605   70.504146   64.379768
# std    174.215384     2.607057   24.795358   16.310664   13.378718
# min      1.000000  2010.000000    0.000000    0.000000    0.000000
# 25%    151.500000  2013.000000  100.000000   61.000000   57.000000
# 50%    302.000000  2015.000000  120.000000   74.000000   66.000000
# 75%    452.500000  2017.000000  129.000000   82.000000   73.000000
# max    603.000000  2019.000000  206.000000   98.000000   97.000000
#
#                dB        live         val         dur       acous        spch  \
# count  603.000000  603.000000  603.000000  603.000000  603.000000  603.000000
# mean    -5.578773   17.774461   52.225539  224.674959   14.326700    8.358209
# std      2.798020   13.102543   22.513020   34.130059   20.766165    7.483162
# min    -60.000000    0.000000    0.000000  134.000000    0.000000    0.000000
# 25%     -6.000000    9.000000   35.000000  202.000000    2.000000    4.000000
# 50%     -5.000000   12.000000   52.000000  221.000000    6.000000    5.000000
# 75%     -4.000000   24.000000   69.000000  239.500000   17.000000    9.000000
# max     -2.000000   74.000000   98.000000  424.000000   99.000000   48.000000
#
#               pop
# count  603.000000
# mean    66.520730
# std     14.517746
# min      0.000000
# 25%     60.000000
# 50%     69.000000
# 75%     76.000000
# max     99.000000

# %%
# drop the unnamed columns since it's just an series of index+1, which we considered that they have no affects to the whole analysis
data = data.drop('Unnamed: 0',axis=1)

# %%
# rename few of columns' name to make it makes more sense
data.rename(columns={'nrgy':'energy',
                     'dnce':'danceability',
                     'dB':'loudness',
                     'live':'liveliness',
                     'val':'valence',
                     'dur':'duration_sec',
                     'acous':'acousticness',
                     'spch':'speechniness',
                     'pop':'popularity'}
                     ,inplace=True)

# %%
data.head()
# Out:
#                   title      artist        top genre  year  bpm  energy  \
# 0      Hey, Soul Sister       Train       neo mellow  2010   97      89
# 1  Love The Way You Lie      Eminem  detroit hip hop  2010   87      93
# 2               TiK ToK       Kesha        dance pop  2010  120      84
# 3           Bad Romance   Lady Gaga        dance pop  2010  119      92
# 4  Just the Way You Are  Bruno Mars              pop  2010  109      84
#
#    danceability  loudness  liveliness  valence  duration_sec  acousticness  \
# 0            67        -4           8       80           217            19
# 1            75        -5          52       64           263            24
# 2            76        -3          29       71           200            10
# 3            70        -4           8       71           295             0
# 4            64        -5           9       43           221             2
#
#    speechniness  popularity
# 0             4          83
# 1            23          82
# 2            14          80
# 3             4          79
# 4             4          78

# %%
data.columns
# Out:
# Index(['title', 'artist', 'top genre', 'year', 'bpm', 'energy', 'danceability',
#        'loudness', 'liveliness', 'valence', 'duration_sec', 'acousticness',
#        'speechniness', 'popularity'],
#       dtype='object')

# %% [markdown]
# ### Statistical review of the data

# %% [markdown]
# #### find out most popular songs

# %%
# find out the most popular song by sorting with descending order
data.sort_values(by=['popularity'],ascending=False)
# Out:
#                        title             artist     top genre  year  bpm  \
# 572                 Memories           Maroon 5           pop  2019   91
# 573      Lose You To Love Me       Selena Gomez     dance pop  2019  102
# 574        Someone You Loved      Lewis Capaldi           pop  2019  110
# 575                 Señorita       Shawn Mendes  canadian pop  2019  117
# 576        How Do You Sleep?          Sam Smith           pop  2019  111
# ..                       ...                ...           ...   ...  ...
# 50                     Hello     Martin Solveig      big room  2010  128
# 362         L.A.LOVE (la la)             Fergie     dance pop  2015  202
# 442        Million Years Ago              Adele  british soul  2016    0
# 138  Blow Me (One Last Kiss)               P!nk     dance pop  2012  114
# 267          Not a Bad Thing  Justin Timberlake     dance pop  2014   86
#
#      energy  danceability  loudness  liveliness  valence  duration_sec  \
# 572      32            76        -7           8       57           189
# 573      34            51        -9          21        9           206
# 574      41            50        -6          11       45           182
# 575      54            76        -6           9       75           191
# 576      68            48        -5           8       35           202
# ..      ...           ...       ...         ...      ...           ...
# 50       98            67        -3          10       45           191
# 362      39            48        -8          26       27           193
# 442       0             0       -60           0        0           227
# 138      92            60        -3          25       75           256
# 267      73            59        -6          38       46           266
#
#      acousticness  speechniness  popularity
# 572            84             5          99
# 573            58             4          97
# 574            75             3          96
# 575             4             3          95
# 576            15             9          93
# ..            ...           ...         ...
# 50              1             3           0
# 362             2             9           0
# 442             0             0           0
# 138             0             4           0
# 267            27             6           0
#
# [603 rows x 14 columns]

# %%
# find out the top 10 songs of 2010s
data.sort_values(by='popularity',ascending=False)[0:10]
# Out:
#                                                  title         artist  \
# 572                                           Memories       Maroon 5
# 573                                Lose You To Love Me   Selena Gomez
# 574                                  Someone You Loved  Lewis Capaldi
# 575                                           Señorita   Shawn Mendes
# 576                                  How Do You Sleep?      Sam Smith
# 578                             Trampoline (with ZAYN)          SHAED
# 577  South of the Border (feat. Camila Cabello & Ca...     Ed Sheeran
# 580                                        Truth Hurts          Lizzo
# 581         Good as Hell (feat. Ariana Grande) - Remix          Lizzo
# 579                                            Happier     Marshmello
#
#         top genre  year  bpm  energy  danceability  loudness  liveliness  \
# 572           pop  2019   91      32            76        -7           8
# 573     dance pop  2019  102      34            51        -9          21
# 574           pop  2019  110      41            50        -6          11
# 575  canadian pop  2019  117      54            76        -6           9
# 576           pop  2019  111      68            48        -5           8
# 578    electropop  2019  127      46            62        -6          14
# 577           pop  2019   98      62            86        -6           9
# 580   escape room  2019  158      62            72        -3          12
# 581   escape room  2019   96      89            67        -3          74
# 579       brostep  2019  100      79            69        -3          17
#
#      valence  duration_sec  acousticness  speechniness  popularity
# 572       57           189            84             5          99
# 573        9           206            58             4          97
# 574       45           182            75             3          96
# 575       75           191             4             3          95
# 576       35           202            15             9          93
# 578       50           184            56             3          92
# 577       67           204            15             8          92
# 580       41           173            11            11          90
# 581       48           159            30             6          90
# 579       67           214            19             5          90

# %%
# find out the top 10 songs of 2018
data[data['year']==2018].sort_values(by=['popularity'],ascending=False)[0:10]
# Out:
#                                title          artist     top genre  year  bpm  \
# 508         One Kiss (with Dua Lipa)   Calvin Harris     dance pop  2018  124
# 510                        I Like It         Cardi B           pop  2018  136
# 509        Havana (feat. Young Thug)  Camila Cabello     dance pop  2018  105
# 511                        New Rules        Dua Lipa     dance pop  2018  116
# 513             no tears left to cry   Ariana Grande     dance pop  2018  122
# 514                            IDGAF        Dua Lipa     dance pop  2018   97
# 512  There's Nothing Holdin' Me Back    Shawn Mendes  canadian pop  2018  122
# 515                      In My Blood    Shawn Mendes  canadian pop  2018  140
# 516                           Wolves    Selena Gomez     dance pop  2018  125
# 517      Dusk Till Dawn - Radio Edit            ZAYN     dance pop  2018  180
#
#      energy  danceability  loudness  liveliness  valence  duration_sec  \
# 508      86            79        -3           8       59           215
# 510      73            82        -4          37       65           253
# 509      52            77        -4          13       39           217
# 511      70            76        -6          15       61           209
# 513      71            70        -6          29       35           206
# 514      54            84        -6           8       51           218
# 512      81            87        -4           8       97           199
# 515      71            62        -7          13       49           211
# 516      80            72        -5          20       31           198
# 517      44            26        -7          11       10           239
#
#      acousticness  speechniness  popularity
# 508             4            11          86
# 510            10            13          85
# 509            18             3          85
# 511             0             7          84
# 513             4             6          84
# 514             4             9          84
# 512            38             6          84
# 515             6             7          83
# 516            12             4          83
# 517            10             4          83

# %%
# create list of dataframe object which contains top 10 songs of each year

annual10 = []
for year in data['year'].unique():
    df = data[data['year'] == year].sort_values(by=['popularity'],ascending=False)[0:10]
    annual10.append(df)

# %%
print(annual10, type(annual10), type(annual10[0]))
# Out:
# [                                         title         artist  \
# 0                             Hey, Soul Sister          Train
# 1                         Love The Way You Lie         Eminem
# 2                                      TiK ToK          Kesha
# 3                                  Bad Romance      Lady Gaga
# 4                         Just the Way You Are     Bruno Mars
# 5                                         Baby  Justin Bieber
# 6                                     Dynamite      Taio Cruz
# 7                                      Secrets    OneRepublic
# 8   Empire State of Mind (Part II) Broken Down    Alicia Keys
# 11                                   Marry You     Bruno Mars
#
#           top genre  year  bpm  energy  danceability  loudness  liveliness  \
# 0        neo mellow  2010   97      89            67        -4           8
# 1   detroit hip hop  2010   87      93            75        -5          52
# 2         dance pop  2010  120      84            76        -3          29
# 3         dance pop  2010  119      92            70        -4           8
# 4               pop  2010  109      84            64        -5           9
# 5      canadian pop  2010   65      86            73        -5          11
# 6         dance pop  2010  120      78            75        -4           4
# 7         dance pop  2010  148      76            52        -6          12
# 8           hip pop  2010   93      37            48        -8          12
# 11              pop  2010  145      83            62        -5          10
#
#     valence  duration_sec  acousticness  speechniness  popularity
# 0        80           217            19             4          83
# 1        64           263            24            23          82
# 2        71           200            10            14          80
# 3        71           295             0             4          79
# 4        43           221             2             4          78
# 5        54           214             4            14          77
# 6        82           203             0             9          77
# 7        38           225             7             4          77
# 8        14           216            74             3          76
# 11       48           230            33             4          73  ,                                                 title           artist  \
# 51                                   A Thousand Years  Christina Perri
# 52                                   Someone Like You            Adele
# 53                                 Give Me Everything          Pitbull
# 54                               Just the Way You Are       Bruno Mars
# 55                                Rolling in the Deep            Adele
# 56                              Run the World (Girls)          Beyoncé
# 57  Moves Like Jagger - Studio Recording From The ...         Maroon 5
# 58                                        Love On Top          Beyoncé
# 59                                            Grenade       Bruno Mars
# 60                                    Tonight Tonight   Hot Chelle Rae
#
#        top genre  year  bpm  energy  danceability  loudness  liveliness  \
# 51     dance pop  2011  139      41            42        -7          11
# 52  british soul  2011  135      33            56        -8          10
# 53     dance pop  2011  129      94            67        -3          30
# 54           pop  2011  109      84            64        -5           9
# 55  british soul  2011  105      76            73        -5           5
# 56     dance pop  2011  127      90            73        -4          37
# 57           pop  2011  128      76            72        -4          32
# 58     dance pop  2011   94      75            65        -5          60
# 59           pop  2011  110      56            71        -7          12
# 60     dance pop  2011  100      78            69        -5          16
#
#     valence  duration_sec  acousticness  speechniness  popularity
# 51       16           285            31             3          81
# 52       28           285            89             3          80
# 53       53           252            19            16          79
# 54       43           221             2             4          78
# 55       52           228            13             3          76
# 56       76           236             0            14          76
# 57       62           201             1             5          76
# 58       65           267             8             9          76
# 59       23           223            15             6          75
# 60       81           200             8            12          75  ,                                        title                    artist  \
# 104                     Titanium (feat. Sia)              David Guetta
# 105                     Locked Out of Heaven                Bruno Mars
# 106                                 Paradise                  Coldplay
# 107                                 Payphone                  Maroon 5
# 108                 What Makes You Beautiful             One Direction
# 109                 I Knew You Were Trouble.              Taylor Swift
# 110                            Call Me Maybe          Carly Rae Jepsen
# 111                Love You Like A Love Song  Selena Gomez & The Scene
# 112                     Set Fire to the Rain                     Adele
# 113  We Are Never Ever Getting Back Together              Taylor Swift
#
#           top genre  year  bpm  energy  danceability  loudness  liveliness  \
# 104       dance pop  2012  126      79            60        -4          13
# 105             pop  2012  144      70            73        -4          31
# 106  permanent wave  2012  140      59            45        -7           8
# 107             pop  2012  110      75            74        -5          29
# 108        boy band  2012  125      79            73        -2           6
# 109             pop  2012   77      47            62        -7           3
# 110    canadian pop  2012  120      58            78        -7          11
# 111       dance pop  2012  117      68            86        -4           7
# 112    british soul  2012  108      68            61        -4          13
# 113             pop  2012   86      68            63        -6          12
#
#      valence  duration_sec  acousticness  speechniness  popularity
# 104       30           245             7            10          80
# 105       87           233             5             4          79
# 106       20           279             5             3          79
# 107       55           231             2             4          79
# 108       89           200             1             7          78
# 109       68           220             0             4          77
# 110       66           193             1             4          76
# 111       92           188             8             5          76
# 112       47           242             0             3          76
# 113       75           193             1             9          75  ,                                                  title               artist  \
# 139                                Underneath the Tree       Kelly Clarkson
# 140                                         Wake Me Up               Avicii
# 141                                   Story of My Life        One Direction
# 142           Just Give Me a Reason (feat. Nate Ruess)                 P!nk
# 143                                       Hall of Fame           The Script
# 144                                               Roar           Katy Perry
# 145                                      We Can't Stop          Miley Cyrus
# 146                 Don't You Worry Child - Radio Edit  Swedish House Mafia
# 147  Get Lucky (feat. Pharrell Williams & Nile Rodg...            Daft Punk
# 148                                      Wrecking Ball          Miley Cyrus
#
#        top genre  year  bpm  energy  danceability  loudness  liveliness  \
# 139    dance pop  2013  160      81            51        -5          21
# 140     big room  2013  124      78            53        -6          16
# 141     boy band  2013  121      66            60        -6          12
# 142    dance pop  2013   95      55            78        -7          13
# 143  celtic rock  2013   85      87            42        -4          12
# 144    dance pop  2013  180      77            55        -5          35
# 145    dance pop  2013   80      62            61        -6          37
# 146     big room  2013  129      84            61        -3          12
# 147      electro  2013  116      81            79        -9          10
# 148    dance pop  2013  120      42            53        -6          11
#
#      valence  duration_sec  acousticness  speechniness  popularity
# 139       69           230             0             5          88
# 140       64           247             0             5          85
# 141       29           245            23             5          81
# 142       44           243            35             5          81
# 143       63           203             7             6          80
# 144       46           224             0             4          78
# 145       48           231             1             3          78
# 146       44           213            11             5          78
# 147       86           248             4             4          77
# 148       35           221            41             3          77  ,                               title             artist   top genre  year  bpm  \
# 210                       All of Me        John Legend  neo mellow  2014  120
# 211                    Stay With Me          Sam Smith         pop  2014   84
# 212                          Summer      Calvin Harris   dance pop  2014  128
# 213  Happy - From "Despicable Me 2"  Pharrell Williams   dance pop  2014  160
# 214                            Rude             MAGIC!         pop  2014  144
# 215                    Shake It Off       Taylor Swift         pop  2014  160
# 216                      Dark Horse         Katy Perry   dance pop  2014  132
# 217                     Hey Brother             Avicii    big room  2014  125
# 218                            Maps           Maroon 5         pop  2014  120
# 219                        Treasure         Bruno Mars         pop  2014  116
#
#      energy  danceability  loudness  liveliness  valence  duration_sec  \
# 210      26            42        -7          13       33           270
# 211      42            42        -6          11       18           173
# 212      86            60        -4          14       74           223
# 213      82            65        -5           9       96           233
# 214      76            77        -5          31       93           225
# 215      80            65        -5          33       94           219
# 216      59            65        -6          17       35           216
# 217      78            55        -5           8       46           255
# 218      71            74        -6           6       88           190
# 219      69            87        -5          32       94           179
#
#      acousticness  speechniness  popularity
# 210            92             3          86
# 211            59             4          85
# 212             2             3          80
# 213            22            18          79
# 214             4             4          79
# 215             6            17          78
# 216             0             5          78
# 217             3             4          78
# 218             2             3          78
# 219             4             4          77  ,                                                  title          artist  \
# 268                                  Thinking out Loud      Ed Sheeran
# 270                                          The Hills      The Weeknd
# 269                               I'm Not The Only One       Sam Smith
# 271                                      Love Yourself   Justin Bieber
# 272                                        Uptown Funk     Mark Ronson
# 273                                  Take Me To Church          Hozier
# 275                                              Sorry   Justin Bieber
# 274                                              Sugar        Maroon 5
# 276                                    FourFiveSeconds         Rihanna
# 277  Love Me Like You Do - From "Fifty Shades Of Grey"  Ellie Goulding
#
#                      top genre  year  bpm  energy  danceability  loudness  \
# 268                        pop  2015   79      45            78        -6
# 270  canadian contemporary r&b  2015  113      56            58        -7
# 269                        pop  2015   82      49            68        -6
# 271               canadian pop  2015  100      38            61       -10
# 272                  dance pop  2015  115      61            86        -7
# 273    irish singer-songwriter  2015  129      66            57        -5
# 275               canadian pop  2015  100      76            65        -4
# 274                        pop  2015  120      79            75        -7
# 276              barbadian pop  2015  206      27            58        -6
# 277                  dance pop  2015  190      61            26        -7
#
#      liveliness  valence  duration_sec  acousticness  speechniness  popularity
# 268          18       59           282            47             3          84
# 270          14       14           242             7             5          84
# 269           8       49           239            53             4          84
# 271          28       52           234            84            44          83
# 272           3       93           270             1             8          82
# 273          12       44           242            63             5          81
# 275          30       41           201             8             5          81
# 274           9       88           235             6             3          81
# 276          13       35           188            88             5          80
# 277          13       28           253            25             5          79  ,                          title            artist                  top genre  \
# 363                  The Hills        The Weeknd  canadian contemporary r&b
# 364              Love Yourself     Justin Bieber               canadian pop
# 365          Cake By The Ocean              DNCE                  dance pop
# 366          Don't Let Me Down  The Chainsmokers                 electropop
# 367        In the Name of Love     Martin Garrix                   big room
# 368                   Into You     Ariana Grande                  dance pop
# 369  This Is What You Came For     Calvin Harris                  dance pop
# 370            Million Reasons         Lady Gaga                  dance pop
# 371                  Needed Me           Rihanna              barbadian pop
# 372                    7 Years      Lukas Graham                 danish pop
#
#      year  bpm  energy  danceability  loudness  liveliness  valence  \
# 363  2016  113      56            58        -7          14       14
# 364  2016  100      38            61       -10          28       52
# 365  2016  119      75            77        -5           4       90
# 366  2016  160      87            53        -5          14       42
# 367  2016  134      52            50        -6          45       17
# 368  2016  108      73            62        -6          14       37
# 369  2016  124      93            63        -3          15       47
# 370  2016  130      42            67        -8          11       15
# 371  2016  111      31            67        -8           8       30
# 372  2016  120      47            77        -6          39       34
#
#      duration_sec  acousticness  speechniness  popularity
# 363           242             7             5          84
# 364           234            84            44          83
# 365           219            15             5          81
# 366           208            16            17          81
# 367           196            11             4          81
# 368           244             2            11          80
# 369           222            20             3          80
# 370           205            49             4          80
# 371           192            11            24          80
# 372           237            29             5          80  ,                   title            artist                  top genre  year  \
# 443        Shape of You        Ed Sheeran                        pop  2017
# 444              Closer  The Chainsmokers                 electropop  2017
# 445             Starboy        The Weeknd  canadian contemporary r&b  2017
# 446    Treat You Better      Shawn Mendes               canadian pop  2017
# 447  That's What I Like        Bruno Mars                        pop  2017
# 448     Let Me Love You          DJ Snake            electronic trap  2017
# 449    I Feel It Coming        The Weeknd  canadian contemporary r&b  2017
# 450               Mercy      Shawn Mendes               canadian pop  2017
# 451        Side To Side     Ariana Grande                  dance pop  2017
# 452                Stay              Zedd                 complextro  2017
#
#      bpm  energy  danceability  loudness  liveliness  valence  duration_sec  \
# 443   96      65            83        -3           9       93           234
# 444   95      52            75        -6          11       66           245
# 445  186      59            68        -7          14       49           230
# 446   83      82            44        -4          11       75           188
# 447  134      56            85        -5           9       86           207
# 448  100      72            65        -5          14       16           206
# 449   93      82            77        -6           7       59           269
# 450  148      66            56        -5          11       36           209
# 451  159      74            65        -6          24       61           226
# 452  102      62            69        -5          12       54           210
#
#      acousticness  speechniness  popularity
# 443            58             8          87
# 444            41             3          86
# 445            14            28          85
# 446            11            34          84
# 447             1             4          83
# 448             9             3          82
# 449            43            12          81
# 450            13             8          81
# 451             5            23          80
# 452            25             6          80  ,                                title          artist     top genre  year  bpm  \
# 508         One Kiss (with Dua Lipa)   Calvin Harris     dance pop  2018  124
# 510                        I Like It         Cardi B           pop  2018  136
# 509        Havana (feat. Young Thug)  Camila Cabello     dance pop  2018  105
# 511                        New Rules        Dua Lipa     dance pop  2018  116
# 513             no tears left to cry   Ariana Grande     dance pop  2018  122
# 514                            IDGAF        Dua Lipa     dance pop  2018   97
# 512  There's Nothing Holdin' Me Back    Shawn Mendes  canadian pop  2018  122
# 515                      In My Blood    Shawn Mendes  canadian pop  2018  140
# 516                           Wolves    Selena Gomez     dance pop  2018  125
# 517      Dusk Till Dawn - Radio Edit            ZAYN     dance pop  2018  180
#
#      energy  danceability  loudness  liveliness  valence  duration_sec  \
# 508      86            79        -3           8       59           215
# 510      73            82        -4          37       65           253
# 509      52            77        -4          13       39           217
# 511      70            76        -6          15       61           209
# 513      71            70        -6          29       35           206
# 514      54            84        -6           8       51           218
# 512      81            87        -4           8       97           199
# 515      71            62        -7          13       49           211
# 516      80            72        -5          20       31           198
# 517      44            26        -7          11       10           239
#
#      acousticness  speechniness  popularity
# 508             4            11          86
# 510            10            13          85
# 509            18             3          85
# 511             0             7          84
# 513             4             6          84
# 514             4             9          84
# 512            38             6          84
# 515             6             7          83
# 516            12             4          83
# 517            10             4          83  ,                                                  title         artist  \
# 572                                           Memories       Maroon 5
# 573                                Lose You To Love Me   Selena Gomez
# 574                                  Someone You Loved  Lewis Capaldi
# 575                                           Señorita   Shawn Mendes
# 576                                  How Do You Sleep?      Sam Smith
# 577  South of the Border (feat. Camila Cabello & Ca...     Ed Sheeran
# 578                             Trampoline (with ZAYN)          SHAED
# 579                                            Happier     Marshmello
# 580                                        Truth Hurts          Lizzo
# 581         Good as Hell (feat. Ariana Grande) - Remix          Lizzo
#
#         top genre  year  bpm  energy  danceability  loudness  liveliness  \
# 572           pop  2019   91      32            76        -7           8
# 573     dance pop  2019  102      34            51        -9          21
# 574           pop  2019  110      41            50        -6          11
# 575  canadian pop  2019  117      54            76        -6           9
# 576           pop  2019  111      68            48        -5           8
# 577           pop  2019   98      62            86        -6           9
# 578    electropop  2019  127      46            62        -6          14
# 579       brostep  2019  100      79            69        -3          17
# 580   escape room  2019  158      62            72        -3          12
# 581   escape room  2019   96      89            67        -3          74
#
#      valence  duration_sec  acousticness  speechniness  popularity
# 572       57           189            84             5          99
# 573        9           206            58             4          97
# 574       45           182            75             3          96
# 575       75           191             4             3          95
# 576       35           202            15             9          93
# 577       67           204            15             8          92
# 578       50           184            56             3          92
# 579       67           214            19             5          90
# 580       41           173            11            11          90
# 581       48           159            30             6          90  ] <class 'list'> <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### Genre analysis

# %%
# find out the unique genre for an entire datasets
data['top genre'].unique()
# Out:
# array(['neo mellow', 'detroit hip hop', 'dance pop', 'pop',
#        'canadian pop', 'hip pop', 'barbadian pop', 'atl hip hop',
#        'australian pop', 'indie pop', 'art pop', 'colombian pop',
#        'big room', 'british soul', 'chicago rap', 'acoustic pop',
#        'permanent wave', 'boy band', 'baroque pop', 'celtic rock',
#        'electro', 'complextro', 'canadian hip hop', 'candy pop',
#        'alaska indie', 'folk-pop', 'metropopolis', 'house',
#        'australian hip hop', 'electropop', 'australian dance',
#        'hollywood', 'canadian contemporary r&b',
#        'irish singer-songwriter', 'tropical house', 'belgian edm',
#        'french indie pop', 'hip hop', 'danish pop', 'latin',
#        'canadian latin', 'electronic trap', 'edm', 'electro house',
#        'downtempo', 'brostep', 'contemporary country', 'moroccan pop',
#        'escape room', 'alternative r&b'], dtype=object)

# %%
# find out the most popularity by genre
data.groupby("top genre").agg(score=('popularity','mean'),
                              qty=('popularity','count')).sort_values(by='score',ascending=False)
# Out:
#                                score  qty
# top genre
# escape room                90.000000    2
# brostep                    86.000000    2
# alternative r&b            84.000000    1
# irish singer-songwriter    81.000000    1
# danish pop                 80.000000    1
# celtic rock                80.000000    1
# electronic trap            79.500000    2
# edm                        78.200000    5
# canadian contemporary r&b  77.666667    9
# electropop                 77.461538   13
# contemporary country       76.000000    1
# pop                        74.833333   60
# electro                    74.500000    2
# detroit hip hop            73.500000    2
# canadian hip hop           73.500000    2
# metropopolis               73.000000    1
# chicago rap                73.000000    1
# canadian pop               72.235294   34
# house                      72.000000    1
# tropical house             71.666667    3
# electro house              70.000000    1
# hip hop                    70.000000    4
# australian hip hop         70.000000    1
# boy band                   69.666667   15
# indie pop                  69.500000    2
# baroque pop                67.500000    2
# complextro                 67.333333    6
# big room                   65.600000   10
# barbadian pop              65.400000   15
# australian pop             65.400000    5
# dance pop                  64.363914  327
# art pop                    62.750000    8
# australian dance           62.333333    6
# latin                      62.250000    4
# british soul               62.181818   11
# downtempo                  61.500000    2
# belgian edm                60.000000    2
# neo mellow                 60.000000    9
# permanent wave             58.750000    4
# candy pop                  58.500000    2
# acoustic pop               58.500000    2
# french indie pop           58.000000    1
# folk-pop                   56.500000    2
# colombian pop              56.000000    3
# hip pop                    55.500000    6
# moroccan pop               53.000000    1
# atl hip hop                50.000000    5
# hollywood                  37.000000    1
# alaska indie               36.000000    1
# canadian latin             18.000000    1

# %% [markdown]
# ### Artist analysis

# %%
# find out top 20 on-chart artist
data.groupby('artist').agg(count=('popularity','count')).sort_values(by='count',ascending=False)[0:20]
# Out:
#                    count
# artist
# Katy Perry            17
# Justin Bieber         16
# Maroon 5              15
# Rihanna               15
# Lady Gaga             14
# Bruno Mars            13
# Shawn Mendes          11
# Ed Sheeran            11
# Pitbull               11
# The Chainsmokers      11
# Adele                 10
# Calvin Harris         10
# Jennifer Lopez        10
# Britney Spears         9
# OneRepublic            9
# Ariana Grande          9
# Justin Timberlake      9
# Kesha                  9
# David Guetta           9
# Demi Lovato            8

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# We will use this section to visualize the data using altair visualization package

# %%
# !pip install altair
# Out:
# Requirement already satisfied: altair in c:\tools\anaconda3\lib\site-packages (5.4.1)
# Requirement already satisfied: jsonschema>=3.0 in c:\tools\anaconda3\lib\site-packages (from altair) (4.16.0)
# Requirement already satisfied: narwhals>=1.5.2 in c:\tools\anaconda3\lib\site-packages (from altair) (1.13.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\tools\anaconda3\lib\site-packages (from altair) (4.12.2)
# Requirement already satisfied: packaging in c:\tools\anaconda3\lib\site-packages (from altair) (21.3)
# Requirement already satisfied: jinja2 in c:\tools\anaconda3\lib\site-packages (from altair) (2.11.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\tools\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\tools\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\tools\anaconda3\lib\site-packages (from jinja2->altair) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\tools\anaconda3\lib\site-packages (from packaging->altair) (3.0.9)

# %%
import altair as alt

# %%
size = 15

hexagon = "M0,-2.3094010768\
        L2,-1.1547005384 \
        2,1.1547005384 \
        0,2.3094010768 \
        -2,1.1547005384 \
        -2,-1.1547005384Z"

xField = 'energy'
yField = 'danceability'

xFeaturesCount = 10
yFeaturesCount = 10

alt.Chart(data).mark_point(size = size**2,
                           shape = hexagon,)\
                            .encode(
                                x = alt.X(
                                    'xFeaturePos:Q',axis=alt.Axis(
                                        title='Energy',
                                        grid=False,
                                        tickOpacity=0,
                                        domainOpacity=0
                                        )
                                    ),
                                y = alt.Y(
                                    'yFeaturePos:Q',axis=alt.Axis(
                                        title='Dancibility',
                                        labelPadding=20,
                                        tickOpacity=0,
                                        domainOpacity=0                                        
                                        )
                                    ),
                                stroke = alt.value('black'),
                                strokeWidth = alt.value(0.2),
                                fill = alt.value('blue'),
                                opacity = alt.value(0.1),                                
                            )\
                            .transform_calculate(
                                xFeaturePos=f'(floor(datum.{xField}/10)+(floor(datum.{yField}/10))%2/2)*10',
                                yFeaturePos=f'(floor(datum.{yField}/10))*10'
                            )\
                            .properties(
                                width = size*xFeaturesCount*2,
                                height = size*yFeaturesCount*1.7320508076   # approx of sin(60°)*2
                            )\
                            .configure_view(
                                strokeWidth = 0
                            )
# Out:
# alt.Chart(...)
